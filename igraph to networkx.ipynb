# %%
# É possivel passar um grafo do igraph para o networkx por lista de arestas (edgelist) porém as medidas calculadas no netwokx 
# sao exatamete a metade ou seja se o max degree do networx é 81 do igrapg sera 162, por teste ainda que 
# as medidaas sejam diferentes o max betweeness do networx é o mesmo vertice do igraph e isso que importa os vertices sao iguais

# %%
import numpy as np
import random
import networkx as nx
import random
import sys
import copy
from igraph import *
import time
import numpy as np

# %%
g = Graph.Read_Ncol("CA-GrQc.txt", directed = False)

# %%
A = g.get_edgelist()
nxg = nx.Graph(A)

# %%
# for i in list(nxg.degree()):
#     if i[1]  == max(grau):
#         print(i)

# %%
for i,j in enumerate(g.degree()):
    if j == max(g.degree()):
        print (i,j)

# %%
my_list = []
a = g.pagerank(g.vs())
my_list.append(a)

a = g.closeness()
my_list.append(a)

# %%
my_list2 = []
a = nx.closeness_centrality(nxg)
my_list2.append(a)

a = nx.pagerank(nxg)
my_list2.append(a)

# %%
# bet = nx.betweenness_centrality(nxg)
# a = g.betweenness()

# %%
i = my_list2[0].values()
j = my_list2[1].values()
k = my_list[0]
l = my_list[1]

# %%
print i.index(max(i))
print j.index(max(j))
print k.index(max(k))
print l.index(max(l))
len(j)
# Out:
# 1037
# 108
# 108
# 1037
# 5242

# %%
max(bet.values())
# Out:
# 0.037027150433897676

# %%
a.index(max(a))
# Out:
# 1037

# %%
bet[1037] == max(bet.values())
# Out:
# True

# %%
dict(nxg.degree())
# Out:
# {0: 8,
#  1: 5,
#  2: 2,
#  3: 5,
#  4: 13,
#  5: 10,
#  6: 17,
#  7: 3,
#  8: 4,
#  9: 8,
#  10: 3,
#  11: 34,
#  12: 7,
#  13: 10,
#  14: 2,
#  15: 17,
#  16: 25,
#  17: 8,
#  18: 1,
#  19: 21,
#  20: 29,
#  21: 3,
#  22: 2,
#  23: 14,
#  24: 12,
#  25: 11,
#  26: 4,
#  27: 20,
#  28: 1,
#  29: 4,
#  30: 2,
#  31: 24,
#  32: 13,
#  33: 8,
#  34: 6,
#  35: 4,
#  36: 18,
#  37: 7,
#  38: 1,
#  39: 1,
#  40: 16,
#  41: 32,
#  42: 9,
#  43: 10,
#  44: 22,
#  45: 23,
#  46: 1,
#  47: 7,
#  48: 16,
#  49: 23,
#  50: 6,
#  51: 2,
#  52: 2,
#  53: 32,
#  54: 9,
#  55: 7,
#  56: 1,
#  57: 4,
#  58: 3,
#  59: 2,
#  60: 6,
#  61: 5,
#  62: 6,
#  63: 4,
#  64: 2,
#  65: 3,
#  66: 3,
#  67: 30,
#  68: 17,
#  69: 9,
#  70: 25,
#  71: 9,
#  72: 68,
#  73: 31,
#  74: 15,
#  75: 9,
#  76: 31,
#  77: 68,
#  78: 5,
#  79: 13,
#  80: 11,
#  81: 22,
#  82: 21,
#  83: 20,
#  84: 25,
#  85: 4,
#  86: 9,
#  87: 9,
#  88: 6,
#  89: 20,
#  90: 13,
#  91: 14,
#  92: 27,
#  93: 8,
#  94: 3,
#  95: 7,
# ...
